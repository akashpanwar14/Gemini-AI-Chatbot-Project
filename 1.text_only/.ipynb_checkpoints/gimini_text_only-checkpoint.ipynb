# %%
 pip install google.generativeai
# Out:
# Collecting google.generativeai
#   Downloading google_generativeai-0.4.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting google-ai-generativelanguage==0.4.0 (from google.generativeai)
#   Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting google-auth>=2.15.0 (from google.generativeai)
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-api-core (from google.generativeai)
#   Downloading google_api_core-2.18.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting protobuf (from google.generativeai)
#   Downloading protobuf-5.26.1-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pydantic (from google.generativeai)
#   Downloading pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
#      ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/85.1 kB ? eta -:--:--
#      ------------- ------------------------ 30.7/85.1 kB 640.0 kB/s eta 0:00:01
#      --------------------------- ---------- 61.4/85.1 kB 544.7 kB/s eta 0:00:01
#      -------------------------------------- 85.1/85.1 kB 598.8 kB/s eta 0:00:00
# Collecting tqdm (from google.generativeai)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (4.10.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.4.0->google.generativeai)
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf (from google.generativeai)
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core->google.generativeai)
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google.generativeai) (2.31.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google.generativeai)
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google.generativeai)
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google.generativeai)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic->google.generativeai)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic->google.generativeai)
#   Downloading pydantic_core-2.16.3-cp312-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from tqdm->google.generativeai) (0.4.6)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google.generativeai)
#   Downloading grpcio-1.62.1-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google.generativeai)
#   Downloading grpcio_status-1.62.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google.generativeai)
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (2024.2.2)
# Downloading google_generativeai-0.4.1-py3-none-any.whl (137 kB)
#    ---------------------------------------- 0.0/137.4 kB ? eta -:--:--
#    -------------------------------- ------- 112.6/137.4 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 133.1/137.4 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 137.4/137.4 kB 1.4 MB/s eta 0:00:00
# Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl (598 kB)
#    ---------------------------------------- 0.0/598.7 kB ? eta -:--:--
#    ---------------- ----------------------- 245.8/598.7 kB 7.6 MB/s eta 0:00:01
#    -------------------- ------------------- 307.2/598.7 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 598.7/598.7 kB 4.7 MB/s eta 0:00:00
# Downloading google_api_core-2.18.0-py3-none-any.whl (138 kB)
#    ---------------------------------------- 0.0/138.3 kB ? eta -:--:--
#    ---------------------------------------- 138.3/138.3 kB 8.0 MB/s eta 0:00:00
# Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.2 kB ? eta -:--:--
#    --------------------------------------- 189.2/189.2 kB 11.2 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 13.0 MB/s eta 0:00:00
# Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    --------------------------------------- 394.9/394.9 kB 25.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.16.3-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.9 MB 54.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.9 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 17.0 MB/s eta 0:00:00
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#    ---------------------------------------- 0.0/229.1 kB ? eta -:--:--
#    ---------------------------------------- 229.1/229.1 kB ? eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB ? eta 0:00:00
# Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.2 kB ? eta -:--:--
#    --------------------------------------- 181.2/181.2 kB 10.7 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading grpcio-1.62.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    --------------- ------------------------ 1.4/3.8 MB 30.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.9/3.8 MB 40.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.9/3.8 MB 40.7 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.8 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 18.5 MB/s eta 0:00:00
# Downloading grpcio_status-1.62.1-py3-none-any.whl (14 kB)
# Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.3 kB ? eta -:--:--
#    ---------------------------------------- 85.3/85.3 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: tqdm, pydantic-core, pyasn1, protobuf, grpcio, cachetools, annotated-types, rsa, pydantic, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-api-core, google-ai-generativelanguage, google.generativeai
# Successfully installed annotated-types-0.6.0 cachetools-5.3.3 google-ai-generativelanguage-0.4.0 google-api-core-2.18.0 google-auth-2.29.0 google.generativeai-0.4.1 googleapis-common-protos-1.63.0 grpcio-1.62.1 grpcio-status-1.62.1 proto-plus-1.23.0 protobuf-4.25.3 pyasn1-0.6.0 pyasn1-modules-0.4.0 pydantic-2.6.4 pydantic-core-2.16.3 rsa-4.9 tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.

# %%
 import google.generativeai as genai
 genai.configure(api_key="AIzaSyClTmL4sjzj4g4-HygpzDsLYcP5XLGZ2Js")
 model = genai.GenerativeModel('gemini-pro')
 response = model.generate_content("What is the meaning of Death?")
 print(response.text)
# Out:
# **Philosophical and Spiritual Perspectives:**
#
# * **End of Physical Life:** The termination of an individual's consciousness and bodily functions.
# * **Transition to Another Realm:** In many religions and belief systems, death is seen as a passage into an afterlife or spiritual realm.
# * **Mystery and Enigma:** The ultimate unknown, an event that has both fascinated and terrified humans throughout history.
# * **Symbol of Change and Transformation:** In some cultures, death is viewed as a necessary step in the cycle of life, death, and rebirth.
# * **Spiritual Reckoning:** A time for reflection and judgment on an individual's actions and beliefs.
#
# **Psychological and Emotional Perspectives:**
#
# * **Loss and Grief:** The profound emotional response to the death of a loved one, including feelings of sadness, anger, and numbness.
# * **Existential Angst:** Death confronts individuals with the finitude of their own lives, leading to questions about meaning and purpose.
# * **Acceptance and Meaning:** Individuals may find ways to cope with death by accepting it as part of life's journey and finding meaning in their experiences.
#
# **Cultural and Societal Perspectives:**
#
# * **Social Rituals and Practices:** Different cultures have established rituals, customs, and beliefs surrounding death, such as funerals, mourning practices, and memorials.
# * **Historical Impact:** Death has played a significant role in shaping human history, influencing art, literature, philosophy, and political decisions.
# * **Taboo and Stigma:** In some cultures, death is associated with fear, stigma, and silence, leading to avoidance and isolation.
#
# **Biological and Scientific Perspectives:**
#
# * **Cellular Death:** The irreversible cessation of cellular functions, leading to the disintegration of the body.
# * **Thanatology:** The scientific study of death, including its physical, physiological, and psychological aspects.
# * **End-of-Life Care:** Palliative and hospice care focuses on providing comfort, symptom relief, and emotional support to individuals facing the end of life.
